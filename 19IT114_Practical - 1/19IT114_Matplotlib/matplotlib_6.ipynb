# %%
import numpy as np
import matplotlib.pyplot as mat
x=np.array([1,1,2,2,2,2,3,3,3,5,4])
mat.hist(x)
mat.show()

# %%
import numpy as np
import matplotlib.pyplot as mat
import random
x = np.array([1,2,3,4,5,6,7,8])
y = np.array([18,15,6,9,4,3,2,1])
mat.scatter(x,y)
x = np.array([random.randint(20,60) for x in range(10)])
y = np.array([random.randint(10,20) for x in range(10)])
mat.scatter(x,y)
mat.show()

# %%
import numpy as np
import matplotlib.pyplot as mat
x = np.array([40,20,20,20])
mat.pie(x)
print(x)
mat.show()
# Out:
# [40 20 20 20]
